# %% [markdown]
# <a href="https://colab.research.google.com/github/cAnnBurns/classroom/blob/main/Distance_vs_Displacement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This activity reviews the difference between distance and displacement. The information covered in this activity is described on pages 38-40 of your textbook. Before you begin, write down the definition of distance and displacement. How are these two terms different? When would you need to use distance? When would displacement be the best value to report?
#
# The code shows the movement of a turtle. The starting position of the turtle is marked with a red dot.
#
# Press the triangle on the left side of each code block to run the code. You can rerun the code to get new numbers. Calculate the distance the turtle travels and the displacement of the turtle. Then, run the next block of code to check your answer.
#
# There are three levels. If you successfully answer level 1 more than 5 times, move on to level 2. If you successfully answer level 2 more than 5 times, move on to level 3.

# %%
#you must run this block of code before doing anything else!

# !pip install ColabTurtlePlus
from ColabTurtlePlus.Turtle import *
import random
from random import Random
import math
# Out:
# ...
# Put clearscreen() as the first line in a cell (after the import command) to re-run turtle commands in the cell

# %% [markdown]
# #**Level 1**
# Run the block of code below to make the turtle move. Using the numbers printed below the turtle's path, calculate the turtle's distance traveled and displacement. Use "steps" for units and North,South,East, or West for direction.

# %%
clearscreen()
initializeTurtle()
penup()
goto(0, 0)
pendown()
dot(12, "red")
distance=0
step1 = random.randint(30,100)
step2 = random.randint(30,100)
turn_direction = random.choice(["left","right"])
angle = random.choice([90,180])

if angle == 90:
  step3=step1
else:
  step3 = random.randint(30,100)

if angle == 180:
  direction1="East"
  direction2="West"
  direction3="East"
else:
  direction1=" "
  direction2=" "
  direction3=" "

if turn_direction == "left":
  forward (step1)
  left(angle)
  forward(step2)
  left(angle)
  forward(step3)

else:
    forward (step1)
    right(angle)
    forward(step2)
    right(angle)
    forward(step3)

print("steps = ", step1, "steps",direction1,", ", step2,"steps",direction2,",", step3,"steps",direction3)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
# ...

# %% [markdown]
# Find the total distance traveled and the displacement of the turtle. Remember that displacement includes direction. For this activity we will use North, South, East or West for direction. We will use steps for our units. Check your answer by running the next block of code.

# %%
distance = step1+step2+step3
print("distance = ",distance, "steps")

if angle==90:
  displacement=step2
  if turn_direction == "left":
    direction = "North"
  else:
    direction = "South"
else:
  displacement = (step1-step2)+step3
  if displacement<0:
    direction = "West"
  else:
    direction = "East"

displacement = abs(displacement)
print("displacement = ", displacement,"steps" ,direction)
# Out:
# distance =  189 steps
# displacement =  95 steps East

# %% [markdown]
# # **Level 2**
# For this level you may need to use [Pythagorean Theorm](https://www.mathsisfun.com/pythagoras.html).

# %%
clearscreen()
initializeTurtle()
penup()
goto(0, 0)
pendown()
dot(12, "red")
distance=0
step1 = random.randint(30,100)
step2 = random.randint(30,100)
step3 = random.randint(30,100)

turn_direction = random.choice(["left","right"])
angle = random.choice([90,180])

if angle == 180:
  direction1="East"
  direction2="West"
  direction3="East"
else:
  direction1=" "
  direction2=" "
  direction3=" "

if turn_direction == "left":
  forward (step1)
  left(angle)
  forward(step2)
  left(angle)
  forward(step3)


else:
    forward (step1)
    right(angle)
    forward(step2)
    right(angle)
    forward(step3)

print("steps = ", step1, "steps",direction1,", ", step2,"steps",direction2,",", step3,"steps",direction3)
print(turn_direction)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="400.0" y1="300.0" x2="471.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="471.0" y1="300.0" x2="471.0" y2="364.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="471.0" y1="364.0" x2="461.0" y2="364.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="461.0" y1="364.0" x2="451.0" y2="364.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="451.0" y1="364.0" x2="441.0" y2="364.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="441.0" y1="364.0" x2="431.0" y2="364.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="431.0" y1="364.0" x2="422.0" y2="364.0" stroke-linecap="round" style="stroke:black;stroke-width:1" />
#         <circle cx="400.0" cy="300.0" r="6.0" fill="red" fill-opacity="1" />
#
# ...

# %% [markdown]
# Find the total distance traveled and the displacement of the turtle. Remember that displacement includes direction. For this activity we will use North, South, East or West for direction. We will use steps for our units. Check your answer by running the next block of code.

# %%
distance = step1+step2+step3
print("distance = ",distance, "steps")

if angle==90 and step2!=step3:
  displacement=math.sqrt(step2**2 + (step1-step3)**2)
  displacement = round(displacement, 2)
  if turn_direction == "left"and step1>step3:
    direction="Northeast"
  elif turn_direction == "left" and step1<step3:
    direction="Northwest"
  elif turn_direction == "right" and step1>step3:
    direction="Southeast"
  else:
    direction ="Southwest"
elif angle==90 and step2==step3:
  displacement=step2
  if turn_direction == "left":
    direction = "North"
  else:
    direction = "South"
else:
  displacement = (step1-step2)+step3
  if displacement<0:
   direction = "West"
   displacement=abs(displacement)
  else:
    direction = "East"

print("displacement = ", displacement,"steps" ,direction)
# Out:
# distance =  184 steps
# displacement =  67.68 steps Southeast

# %% [markdown]
# # **Level 3**
# Now the turtle can move more than 3 times.

# %%
clearscreen()
initializeTurtle()
penup()
goto(0, 0)
pendown()
dot(12, "red")
distance=0
steps_list = []

for i in range(4):
   steps = int(random.random() * 100)
   steps_list.append(steps)

step1, step2, step3, step4 = steps_list

turn_direction = random.choice(["left","right"])
angle = random.choice([90,180])

if angle == 180:
  direction1="East"
  direction2="West"
  direction3="East"
  direction4="West"
else:
  direction1=" "
  direction2=" "
  direction3=" "
  direction4=" "

if turn_direction == "left":
  forward (step1)
  left(angle)
  forward(step2)
  left(angle)
  forward(step3)
  left(angle)
  forward(step4)

else:
    forward (step1)
    right(angle)
    forward(step2)
    right(angle)
    forward(step3)
    right(angle)
    forward(step4)

print("steps = ", step1, "steps",direction1,", ", step2,"steps",direction2,",", step3,"steps",direction3, "steps ", step4, direction4)
print(turn_direction)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <line x1="400.0" y1="300.0" x2="462.0" y2="300.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="462.0" y1="300.0" x2="462.0" y2="282.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="462.0" y1="282.0" x2="434.0" y2="282.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="434.0" y1="282.0" x2="434.0" y2="292.0" stroke-linecap="round" style="stroke:black;stroke-width:1" /><line x1="434.0" y1="292.0" x2="434.0" y2="299.0" stroke-linecap="round" style="stroke:black;stroke-width:1" />
#         <circle cx="400.0" cy="300.0" r="6.0" fill="red" fill-opacity="1" />
#
#         <g id="classic" visibility="visible" transform="rotate(0,434.0,299.0) translate(434.0, 299.0)">
# ...

# %%
distance = step1+step2+step3+step4
print("distance = ",distance, "steps")

if turn_direction=="right" and angle==90:
  displacement=math.sqrt((step1-step3)**2 + (step4-step2)**2)
  displacementRD = round(displacement,2)
  if step1>step3 and step2>step4:
    direction = "Southeast"
  elif step1>step3 and step2<step4:
    direction =  "Northeast"
  elif step1<step3 and step2<step4:
    direction = "Northwest"
  else:
    direction = "Southwest"

elif turn_direction=="left" and angle==90:
  displacement=math.sqrt((step4-step2)**2 + (step3-step1)**2)
  displacementRD = round(displacement,2)
  if step1>step3 and step2>step4:
    direction = "Northeast"
  elif step1>step3 and step2<step4:
    direction =  "Northwest"
  elif step1<step3 and step2<step4:
    direction = "Southwest"
  else:
    direction = "Southeast"

elif turn_direction=="left" and angle==180:
  displacement=(((step1-step2)+step3)-step4)
  displacmentRD=abs(displacement)
  direction = "East"

else:
  displacement=(((step1-step2)+step3)-step4)
  displacementRD=abs(displacement)
  direction = "West"

print("displacement = ", displacementRD, direction)
# Out:
# distance =  125 steps
# displacement =  34.01 Northeast
